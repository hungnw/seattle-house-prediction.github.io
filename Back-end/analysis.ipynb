# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("Resources/vgsales.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
Total = data['Global_Sales'].sum()
print (Total)
# Out:
# 8920.44

# %%
publisher = data.groupby("Publisher")[["NA_Sales","Global_Sales"]].sum().sort_values("Global_Sales", ascending = False).head(15)
publisher
# Out:
#                                         NA_Sales  Global_Sales
# Publisher
# Nintendo                                  816.87       1786.56
# Electronic Arts                           595.07       1110.32
# Activision                                429.70        727.46
# Sony Computer Entertainment               265.22        607.50
# Ubisoft                                   253.43        474.72
# Take-Two Interactive                      220.49        399.54
# THQ                                       208.77        340.77
# Konami Digital Entertainment               92.16        283.64
# Sega                                      109.40        272.99
# Namco Bandai Games                         69.52        254.09
# Microsoft Game Studios                    155.35        245.79
# Capcom                                     78.59        200.89
# Atari                                     110.04        157.22
# Warner Bros. Interactive Entertainment     81.18        153.89
# ...

# %%
publisher.to_json("sales_by_publisher.json")

# %%
year = data.groupby("Year")[["Global_Sales"]].sum().sort_values("Global_Sales", ascending = False)
year.to_json("sales_by_year.json")

# %%
year = data.groupby("Year")[["NA_Sales","EU_Sales","JP_Sales","Other_Sales", "Global_Sales"]].sum()
year
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1980.0     10.59      0.67      0.00         0.12         11.38
# 1981.0     33.40      1.96      0.00         0.32         35.77
# 1982.0     26.92      1.65      0.00         0.31         28.86
# 1983.0      7.76      0.80      8.10         0.14         16.79
# 1984.0     33.28      2.10     14.27         0.70         50.36
# 1985.0     33.73      4.74     14.56         0.92         53.94
# 1986.0     12.50      2.84     19.81         1.93         37.07
# 1987.0      8.46      1.41     11.63         0.20         21.74
# 1988.0     23.87      6.59     15.76         0.99         47.22
# 1989.0     45.15      8.44     18.36         1.50         73.45
# 1990.0     25.46      7.63     14.88         1.40         49.39
# 1991.0     12.76      3.95     14.78         0.74         32.23
# 1992.0     33.87     11.71     28.91         1.65         76.16
# 1993.0     15.12      4.65     25.33         0.89         45.98
# ...

# %%
region = year.T.reset_index()
region = region.rename(columns={'index':'Region'})
region
# Out:
# Year        Region  1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  \
# 0         NA_Sales   10.59   33.40   26.92    7.76   33.28   33.73   12.50
# 1         EU_Sales    0.67    1.96    1.65    0.80    2.10    4.74    2.84
# 2         JP_Sales    0.00    0.00    0.00    8.10   14.27   14.56   19.81
# 3      Other_Sales    0.12    0.32    0.31    0.14    0.70    0.92    1.93
# 4     Global_Sales   11.38   35.77   28.86   16.79   50.36   53.94   37.07
#
# Year  1987.0  1988.0  ...  2009.0  2010.0  2011.0  2012.0  2013.0  2014.0  \
# 0       8.46   23.87  ...  338.85  304.24  241.06  154.96  154.77  131.97
# 1       1.41    6.59  ...  191.59  176.73  167.44  118.78  125.80  125.65
# 2      11.63   15.76  ...   61.89   59.49   53.04   51.74   47.59   39.46
# 3       0.20    0.99  ...   74.77   59.90   54.39   37.82   39.82   40.02
# 4      21.74   47.22  ...  667.30  600.45  515.99  363.54  368.11  337.05
#
# Year  2015.0  2016.0  2017.0  2020.0
# ...

# %%
region.to_csv("Yearly_sales_per_region2.csv")

# %%
region.T.to_json("Sales_by_year_per_region.json")

# %%
year_reset = year.reset_index()
year_reset
# Out:
#       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0   1980.0     10.59      0.67      0.00         0.12         11.38
# 1   1981.0     33.40      1.96      0.00         0.32         35.77
# 2   1982.0     26.92      1.65      0.00         0.31         28.86
# 3   1983.0      7.76      0.80      8.10         0.14         16.79
# 4   1984.0     33.28      2.10     14.27         0.70         50.36
# 5   1985.0     33.73      4.74     14.56         0.92         53.94
# 6   1986.0     12.50      2.84     19.81         1.93         37.07
# 7   1987.0      8.46      1.41     11.63         0.20         21.74
# 8   1988.0     23.87      6.59     15.76         0.99         47.22
# 9   1989.0     45.15      8.44     18.36         1.50         73.45
# 10  1990.0     25.46      7.63     14.88         1.40         49.39
# 11  1991.0     12.76      3.95     14.78         0.74         32.23
# 12  1992.0     33.87     11.71     28.91         1.65         76.16
# ...

# %%
year_reset.to_json("sales_by_year_by_region.json")

# %%
year_reset.T.to_json("sales_by_year_reset.json")

# %%
year.T.to_json("sales_by_yearT1.json")

# %%
region = year.T.reset_index()
region = region.rename(columns={'index':'Region'})
region
# Out:
# Year        Region  1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  \
# 0         NA_Sales   10.59   33.40   26.92    7.76   33.28   33.73   12.50
# 1         EU_Sales    0.67    1.96    1.65    0.80    2.10    4.74    2.84
# 2         JP_Sales    0.00    0.00    0.00    8.10   14.27   14.56   19.81
# 3      Other_Sales    0.12    0.32    0.31    0.14    0.70    0.92    1.93
# 4     Global_Sales   11.38   35.77   28.86   16.79   50.36   53.94   37.07
#
# Year  1987.0  1988.0  ...  2009.0  2010.0  2011.0  2012.0  2013.0  2014.0  \
# 0       8.46   23.87  ...  338.85  304.24  241.06  154.96  154.77  131.97
# 1       1.41    6.59  ...  191.59  176.73  167.44  118.78  125.80  125.65
# 2      11.63   15.76  ...   61.89   59.49   53.04   51.74   47.59   39.46
# 3       0.20    0.99  ...   74.77   59.90   54.39   37.82   39.82   40.02
# 4      21.74   47.22  ...  667.30  600.45  515.99  363.54  368.11  337.05
#
# Year  2015.0  2016.0  2017.0  2020.0
# ...

# %%
year.to_json("sales_by_genre.json")

# %%
genre = data.groupby("Genre")[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum().sort_values("Global_Sales", ascending = False)
genre
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          877.83    525.00    159.95       187.38       1751.18
# Sports          683.35    376.85    135.37       134.97       1330.93
# Shooter         582.60    313.27     38.28       102.69       1037.37
# Role-Playing    327.28    188.06    352.31        59.61        927.37
# Platform        447.05    201.63    130.77        51.59        831.37
# Misc            410.24    215.98    107.76        75.32        809.96
# Racing          359.42    238.39     56.69        77.27        732.04
# Fighting        223.59    101.32     87.35        36.68        448.91
# Simulation      183.31    113.38     63.70        31.52        392.20
# Puzzle          123.78     50.78     57.31        12.55        244.95
# Adventure       105.80     64.13     52.07        16.81        239.04
# Strategy         68.70     45.34     49.46        11.36        175.12

# %%
region = genre.T.reset_index()
region = region.rename(columns={'index':'Region'})
region
# Out:
# Genre        Region   Action   Sports  Shooter  Role-Playing  Platform  \
# 0          NA_Sales   877.83   683.35   582.60        327.28    447.05
# 1          EU_Sales   525.00   376.85   313.27        188.06    201.63
# 2          JP_Sales   159.95   135.37    38.28        352.31    130.77
# 3       Other_Sales   187.38   134.97   102.69         59.61     51.59
# 4      Global_Sales  1751.18  1330.93  1037.37        927.37    831.37
#
# Genre    Misc  Racing  Fighting  Simulation  Puzzle  Adventure  Strategy
# 0      410.24  359.42    223.59      183.31  123.78     105.80     68.70
# 1      215.98  238.39    101.32      113.38   50.78      64.13     45.34
# 2      107.76   56.69     87.35       63.70   57.31      52.07     49.46
# 3       75.32   77.27     36.68       31.52   12.55      16.81     11.36
# 4      809.96  732.04    448.91      392.20  244.95     239.04    175.12

# %%
region.T.to_json("genre_by_region.json")

# %%
genre = genre.reset_index()
genre
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         Action    877.83    525.00    159.95       187.38       1751.18
# 1         Sports    683.35    376.85    135.37       134.97       1330.93
# 2        Shooter    582.60    313.27     38.28       102.69       1037.37
# 3   Role-Playing    327.28    188.06    352.31        59.61        927.37
# 4       Platform    447.05    201.63    130.77        51.59        831.37
# 5           Misc    410.24    215.98    107.76        75.32        809.96
# 6         Racing    359.42    238.39     56.69        77.27        732.04
# 7       Fighting    223.59    101.32     87.35        36.68        448.91
# 8     Simulation    183.31    113.38     63.70        31.52        392.20
# 9         Puzzle    123.78     50.78     57.31        12.55        244.95
# 10     Adventure    105.80     64.13     52.07        16.81        239.04
# 11      Strategy     68.70     45.34     49.46        11.36        175.12

# %%
genre.to_json("sales_by_genre3.json")

# %%
genre.T.to_json("sales_by_genre2.json")

# %%
platform = data.groupby("Platform")[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum().sort_values("Global_Sales", ascending = False)
platform
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS2         583.84    339.29    139.20       193.44       1255.64
# X360        601.05    280.58     12.43        85.54        979.96
# PS3         392.26    343.71     79.99       141.93        957.84
# Wii         507.71    268.38     69.35        80.61        926.71
# DS          390.71    194.65    175.57        60.53        822.49
# PS          336.51    213.60    139.82        40.91        730.66
# GBA         187.54     75.25     47.33         7.73        318.50
# PSP         108.99     68.25     76.79        42.19        296.28
# PS4          96.80    123.70     14.30        43.36        278.10
# PC           93.28    139.68      0.17        24.86        258.82
# XB          186.69     60.95      1.38         8.72        258.26
# GB          114.32     47.82     85.12         8.20        255.45
# NES         125.94     21.15     98.65         5.31        251.07
# ...

# %%
platform.T
# Out:
# Platform          PS2    X360     PS3     Wii      DS      PS     GBA     PSP  \
# NA_Sales       583.84  601.05  392.26  507.71  390.71  336.51  187.54  108.99
# EU_Sales       339.29  280.58  343.71  268.38  194.65  213.60   75.25   68.25
# JP_Sales       139.20   12.43   79.99   69.35  175.57  139.82   47.33   76.79
# Other_Sales    193.44   85.54  141.93   80.61   60.53   40.91    7.73   42.19
# Global_Sales  1255.64  979.96  957.84  926.71  822.49  730.66  318.50  296.28
#
# Platform         PS4      PC  ...    SAT    GEN     DC   SCD    NG    WS  \
# NA_Sales       96.80   93.28  ...   0.72  19.27   5.43  1.00  0.00  0.00
# EU_Sales      123.70  139.68  ...   0.54   5.52   1.69  0.36  0.00  0.00
# JP_Sales       14.30    0.17  ...  32.26   2.67   8.56  0.45  1.44  1.42
# Other_Sales    43.36   24.86  ...   0.07   0.89   0.27  0.05  0.00  0.00
# Global_Sales  278.10  258.82  ...  33.59  28.36  15.97  1.87  1.44  1.42
#
# Platform      TG16  3DO    GG  PCFX
# ...

# %%
platform.T.to_json("sales_by_platformT.json")

# %%
platform
# Out:
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     583.84    339.29    139.20       193.44       1255.64
# 1     601.05    280.58     12.43        85.54        979.96
# 2     392.26    343.71     79.99       141.93        957.84
# 3     507.71    268.38     69.35        80.61        926.71
# 4     390.71    194.65    175.57        60.53        822.49
# 5     336.51    213.60    139.82        40.91        730.66
# 6     187.54     75.25     47.33         7.73        318.50
# 7     108.99     68.25     76.79        42.19        296.28
# 8      96.80    123.70     14.30        43.36        278.10
# 9      93.28    139.68      0.17        24.86        258.82
# 10    186.69     60.95      1.38         8.72        258.26
# 11    114.32     47.82     85.12         8.20        255.45
# 12    125.94     21.15     98.65         5.31        251.07
# 13     78.87     58.52     97.35        12.63        247.46
# 14    139.02     41.06     34.22         4.38        218.88
# ...

# %%
platform.to_json("sales_by_platform.json")

# %%
platform.to_csv("sales_by_platform.csv")
